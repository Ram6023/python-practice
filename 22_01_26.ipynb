# %% [markdown]
# <a href="https://colab.research.google.com/github/Ram6023/python-practice/blob/main/22_01_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Advertising.csv')
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Unnamed: 0    False
# TV            False
# Radio         False
# Newspaper     False
# Sales         False
# dtype: bool

# %%
sns.histplot(x=df['TV'],kde=True,bins=30)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=df['Radio'],kde=True,bins=30)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=df['Newspaper'],kde=True,bins=30)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x=df['Sales'],kde=True,bins=30)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
df['TV'].skew()
# Out:
# np.float64(-0.06985336213274573)

# %%
df['Newspaper'].skew()
# Out:
# np.float64(0.8947204074986175)

# %%
df['Sales'].skew()
# Out:
# np.float64(0.4075714250767127)

# %%
df['Radio'].skew()
# Out:
# np.float64(0.09417463149664404)

# %%
sns.scatterplot(x=df['Sales'],y=df['Radio'])
# Out:
# <Axes: xlabel='Sales', ylabel='Radio'>

# %%
sns.scatterplot(x=df['Sales'],y=df['TV'])
# Out:
# <Axes: xlabel='Sales', ylabel='TV'>

# %%
sns.scatterplot(x=df['Sales'],y=df['Newspaper'])
# Out:
# <Axes: xlabel='Sales', ylabel='Newspaper'>

# %%
sns.scatterplot(x=df['Sales'],y=df['Unnamed: 0'])
# Out:
# <Axes: xlabel='Sales', ylabel='Unnamed: 0'>

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='Reds') # to check relation
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
#Step 1 Independent and dependent variable creation
x=df[['TV']]
y=df.Sales

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.46138746336817515

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE :", mean_absolute_error(y_test,y_predict))
print("RMSE :", np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# MSE :  13.06226628830567
# MAE : 2.990565035759226
# RMSE : 3.6141757412037494

# %%
#Step 1 Independent and dependent variable creation
x=df[['Radio']]
y=df.Sales

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.3786450118378575

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE :", mean_absolute_error(y_test,y_predict))
print("RMSE :", np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# MSE :  15.068910882943154
# MAE : 3.2689170364697824
# RMSE : 3.881869508747448

# %%
#Step 1 Independent and dependent variable creation
x=df[['Newspaper']]
y=df.Sales

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# -0.11728796161004928

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE :", mean_absolute_error(y_test,y_predict))
print("RMSE :", np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# MSE :  27.09612547552867
# MAE : 3.992290912504232
# RMSE : 5.205393882841976

# %%
#Step 1 Independent and dependent variable creation
X=df[['TV','Radio']] ## X variable contains all inputs
y=df.Sales ## y is output

# %%
X
# Out:
#         TV  Radio
# 0    230.1   37.8
# 1     44.5   39.3
# 2     17.2   45.9
# 3    151.5   41.3
# 4    180.8   10.8
# ..     ...    ...
# 195   38.2    3.7
# 196   94.2    4.9
# 197  177.0    9.3
# 198  283.6   42.0
# 199  232.1    8.6
#
# [200 rows x 2 columns]
