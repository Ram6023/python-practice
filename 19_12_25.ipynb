# %% [markdown]
# <a href="https://colab.research.google.com/github/Ram6023/python-practice/blob/main/19_12_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.get_dataset_names ()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    bool
#  1   pclass       891 non-null    bool
#  2   sex          891 non-null    bool
#  3   age          891 non-null    bool
#  4   sibsp        891 non-null    bool
#  5   parch        891 non-null    bool
#  6   fare         891 non-null    bool
#  7   embarked     891 non-null    bool
#  8   class        891 non-null    bool
#  9   who          891 non-null    bool
#  10  adult_male   891 non-null    bool
#  11  deck         891 non-null    bool
#  12  embark_town  891 non-null    bool
#  13  alive        891 non-null    bool
#  14  alone        891 non-null    bool
# dtypes: bool(15)
# memory usage: 13.2 KB

# %%
df = df.drop(columns=['deck'])

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %% [markdown]
# # scatter plot

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='fare')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='adult_male', y='alone')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='adult_male')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='fare', y='adult_male')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='pclass')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='pclass', y='age')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='sibsp')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='parch', y='pclass')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='parch', y='fare')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='fare', y='pclass')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='age')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='parch')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='pclass')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='fare')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='parch')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='fare')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='pclass')
plt.show()

# %%
df.median(numeric_only=True)
# Out:
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
df.mode(numeric_only=True)
# Out:
#    survived  pclass   age  sibsp  parch  fare  adult_male  alone
# 0         0       3  24.0      0      0  8.05        True   True

# %% [markdown]
# # barplots
# # 48 combinations of both numerical and categorical data

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['sex' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['embarked' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['class' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['who' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['adult_male' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['embark_town' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['alive' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['age'],y=df['alone' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['sex' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['embarked' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['class' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['who' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['adult_male' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['embark_town' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['alive' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['survived'],y=df['alone' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['sex' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['embarked' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['class' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['who' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['adult_male' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['embark_town' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['alive' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['pclass'],y=df['alone' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['sex' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['fare' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['embarked' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['class' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['who' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['adult_male' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['embark_town' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['alone' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['sibsp'],y=df['alive' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['sex' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['embarked' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['class' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['who' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['adult_male' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['embark_town' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['alone' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['parch'],y=df['alive' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['sex' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['embarked' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['class' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['who' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['adult_male' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['embark_town' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['alive' ], estimator='mean' )
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['fare'],y=df['alone' ], estimator='mean' )
plt.show()

# %% [markdown]
# # univariate with boxplot

# %%
sns.boxplot(x=df['age'])
plt.show()

# %%
sns.boxplot(x=df['fare'])
plt.show()

# %%
sns.boxplot(x=df['survived'])
plt.show()

# %%
sns.boxplot(x=df['parch'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'])
plt.show()

# %%
sns.boxplot(x=df['pclass'])
plt.show()

# %% [markdown]
# # bivariate with boxplot

# %%
sns.boxplot(x=df['age'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['embarked'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['age'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['embarked'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['survived'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['embarked'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['pclass'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['embarked'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['sibsp'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['embarked'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['alone'])
plt.show()

# %%
sns.boxplot(x=df['parch'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['sex'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['embarked'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['class'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['who'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['adult_male'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['embark_town'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['alive'])
plt.show()

# %%
sns.boxplot(x=df['fare'],y=df['alone'])
plt.show()

# %% [markdown]
# # strip plot

# %%
sns.stripplot(x=df['embarked'],y=df['sex'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['sex'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['sex'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['sex'])
plt.show()

# %%
sns.stripplot(x=df['embark_town'],y=df['sex'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['sex'])
plt.show()

# %%
sns.stripplot(x=df['alone'],y=df['sex'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['embarked'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['embarked'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['embarked'])
plt.show()

# %%
sns.stripplot(x=df['embark_town'],y=df['embarked'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['embarked'])
plt.show()

# %%
sns.stripplot(x=df['alone'],y=df['embarked'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['embarked'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['alone'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['embarked'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['embark_town'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['alone'],y=df['class'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['embarked'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['embark_town'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['alone'],y=df['who'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['embarked'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['embark_town'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['alone'],y=df['adult_male'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['embark_town'])
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sex', y='age', hue='class')
plt.title('Age by Sex, colored by Class')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='sex', y='fare', hue='pclass')
plt.title('Fare by Sex, colored by Pclass')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='sex', y='sibsp', hue='alive')
plt.title('Siblings/Spouses by Sex, colored by Alive Status')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='sex', y='parch', hue='alone')
plt.title('Parents/Children by Sex, colored by Alone Status')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='class', y='age', hue='sex')
plt.title('Age by Class, colored by Sex')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='class', y='fare', hue='embarked')
plt.title('Fare by Class, colored by Embarked Port')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='class', y='sibsp', hue='who')
plt.title('Siblings/Spouses by Class, colored by Who')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='class', y='parch', hue='adult_male')
plt.title('Parents/Children by Class, colored by Adult Male Status')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='embarked', y='fare', hue='class')
plt.title('Fare by Embarked Port, colored by Class')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='embarked', y='age', hue='sex')
plt.title('Age by Embarked Port, colored by Sex')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='embark_town', y='pclass', hue='alive')
plt.title('Pclass by Embark Town, colored by Alive Status')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='alive', y='age', hue='sex')
plt.title('Age by Alive Status, colored by Sex')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='alive', y='fare', hue='class')
plt.title('Fare by Alive Status, colored by Class')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='alive', y='sibsp', hue='who')
plt.title('Siblings/Spouses by Alive Status, colored by Who')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='alive', y='parch', hue='adult_male')
plt.title('Parents/Children by Alive Status, colored by Adult Male Status')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='alone', y='fare', hue='class')
plt.title('Fare by Alone Status, colored by Class')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='alone', y='age', hue='sex')
plt.title('Age by Alone Status, colored by Sex')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='adult_male', y='fare', hue='alive')
plt.title('Fare by Adult Male Status, colored by Alive Status')
plt.show()

plt.figure()
sns.scatterplot(data=df, x='adult_male', y='pclass', hue='sex')
plt.title('Pclass by Adult Male Status, colored by Sex')
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['alone'],y=df['embark_town'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['embarked'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['embark_town'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['alone'],y=df['alive'])
plt.show()

# %%
sns.stripplot(x=df['sex'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['embarked'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['class'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['who'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['adult_male'],y=df['alone'])
plt.show()

# %%
sns.stripplot(x=df['alive'],y=df['alone'])
plt.show()

# %% [markdown]
# x,y-num,hue-cat

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='age',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='sibsp',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='parch',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='fare',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='pclass',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='sibsp',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='parch',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='fare',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='pclass',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='parch',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='fare',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='pclass',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='parch', y='fare',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='parch', y='pclass',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='fare', y='pclass',hue='sex')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='age',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='sibsp',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='parch',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='fare',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='pclass',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='sibsp',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='parch',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='fare',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='age', y='pclass',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='parch',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='fare',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='pclass',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='fare', y='parch',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='pclass', y='parch',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='fare', y='pclass',hue='embarked')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='age',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='sibsp',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='parch',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='survived', y='fare',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='age',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='parch', y='age',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='fare', y='age',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='pclass', y='age',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='parch',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='fare',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='pclass',hue='class')
plt.show()

# %%
plt.figure()
sns.scatterplot(data=df, x='sibsp', y='parch',hue='class')
plt.show()

# %%
plt.figure()
sns.barplot(data=df, x='parch', y='fare', hue='class',dodge=True)
plt.show()
