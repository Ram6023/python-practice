# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
data.head(10) # prints first 5
# Out:
#    UserId  TransactionId               TransactionTime  ItemCode  \
# 0  278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1  337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2  267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3  380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4      -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
# 5  285957        6307136  Fri Jan 11 09:50:00 IST 2019   1787247
# 6  345954        6162981  Fri Sep 28 10:51:00 IST 2018    471576
# 7      -1        6143225  Mon Sep 10 11:58:00 IST 2018    447867
# 8  339822        6255403  Mon Dec 10 09:23:00 IST 2018   1783845
# 9  328440        6387425  Sat Feb 16 10:35:00 IST 2019    494802
#
#                        ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0     FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# 1                LONDON BUS COFFEE MUG                       3         3.52
# ...

# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
data.tail()  # prints last 5
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 1083813  313131        6040298  Mon Jun 18 09:18:00 IST 2018    437976
# 1083814  295743        6387117  Sat Feb 16 09:14:00 IST 2019    484113
# 1083815      -1        6361817  Tue Feb 05 05:26:00 IST 2019    497595
# 1083816  324765        5945500  Fri Mar 23 06:26:00 IST 2018    470883
# 1083817  351645        6118145  Tue Aug 21 08:21:00 IST 2018    471849
#
#                           ItemDescription  NumberOfItemsPurchased  \
# 1083813  DENIM PATCH PURSE PINK BUTTERFLY                      30
# 1083814        RECYCLED ACAPULCO MAT PINK                       6
# 1083815              DOILY THANK YOU CARD                      15
# 1083816          REGENCY CAKESTAND 3 TIER                      48
# 1083817             HEART OF WICKER SMALL                       9
#
#          CostPerItem         Country
# 1083813         2.28            EIRE
# 1083814        11.39  United Kingdom
# ...

# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
print(data)  # prints entire data
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 0        278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1        337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2        267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3        380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4            -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
# ...         ...            ...                           ...       ...
# 1083813  313131        6040298  Mon Jun 18 09:18:00 IST 2018    437976
# 1083814  295743        6387117  Sat Feb 16 09:14:00 IST 2019    484113
# 1083815      -1        6361817  Tue Feb 05 05:26:00 IST 2019    497595
# 1083816  324765        5945500  Fri Mar 23 06:26:00 IST 2018    470883
# 1083817  351645        6118145  Tue Aug 21 08:21:00 IST 2018    471849
#
#                            ItemDescription  NumberOfItemsPurchased  \
# ...

# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
data[50:150]  # prints from 50 to 149
# Out:
#      UserId  TransactionId               TransactionTime  ItemCode  \
# 50       -1        6149418  Sun Sep 16 11:31:00 IST 2018    474873
# 51   371175        6183606  Mon Oct 15 06:45:00 IST 2018    440538
# 52   313992        6275643  Sun Dec 23 06:33:00 IST 2018    461664
# 53   327684        6288656  Sun Dec 30 10:47:00 IST 2018    465738
# 54   336420        6359661  Mon Feb 04 07:18:00 IST 2019    490455
# ..      ...            ...                           ...       ...
# 145  300258        6255425  Mon Dec 10 09:32:00 IST 2018   1787079
# 146  330876        6037504  Sat Jun 16 10:00:00 IST 2018    486759
# 147  305025        6352280  Fri Feb 01 07:37:00 IST 2019    455322
# 148      -1        6108674  Tue Aug 14 07:12:00 IST 2018   1780905
# 149  364266        6092163  Tue Jul 31 07:41:00 IST 2018    482916
#
#                        ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 50         PACK OF 20 SPACEBOY NAPKINS                       3         2.25
# ...

# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
data[:101]  # prints 0 to 100
# Out:
#      UserId  TransactionId               TransactionTime  ItemCode  \
# 0    278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1    337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2    267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3    380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4        -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
# ..      ...            ...                           ...       ...
# 96   278313        5941056  Sun Mar 18 11:43:00 IST 2018    471891
# 97   267708        6366327  Wed Feb 06 07:41:00 IST 2019    435855
# 98   324429        6021620  Mon Jun 04 06:43:00 IST 2018    442680
# 99       -1        5921839  Wed Feb 21 10:59:00 IST 2018    457989
# 100  313131        6333261  Wed Jan 23 06:32:00 IST 2019    464898
#
#                          ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# 0       FAMILY ALBUM WHITE PICTURE FRAME                       6        11.73
# ...

# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
data[:-5]  # reomoves last 5 records and print
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 0        278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 1        337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 2        267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 3        380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 4            -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
# ...         ...            ...                           ...       ...
# 1083808  355488        6160286  Tue Sep 25 09:11:00 IST 2018    478191
# 1083809  321531        6037493  Sat Jun 16 09:57:00 IST 2018    441693
# 1083810      -1        6106650  Sun Aug 12 11:53:00 IST 2018    446040
# 1083811  352191        5973242  Mon Apr 16 10:37:00 IST 2018    466599
# 1083812  261681        6153092  Wed Sep 19 06:23:00 IST 2018    477330
#
#                              ItemDescription  NumberOfItemsPurchased  \
# ...

# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
data[::-1]  # prints last to first
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 1083817  351645        6118145  Tue Aug 21 08:21:00 IST 2018    471849
# 1083816  324765        5945500  Fri Mar 23 06:26:00 IST 2018    470883
# 1083815      -1        6361817  Tue Feb 05 05:26:00 IST 2019    497595
# 1083814  295743        6387117  Sat Feb 16 09:14:00 IST 2019    484113
# 1083813  313131        6040298  Mon Jun 18 09:18:00 IST 2018    437976
# ...         ...            ...                           ...       ...
# 4            -1        6143225  Mon Sep 10 11:58:00 IST 2018   1733592
# 3        380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 2        267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 1        337701        6283376  Wed Dec 26 09:06:00 IST 2018    482370
# 0        278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
#
#                            ItemDescription  NumberOfItemsPurchased  \
# ...

# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
data[::3]  # Display every third row from the DataFrame, starting from the first row
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 0        278166        6355745  Sat Feb 02 12:50:00 IST 2019    465549
# 3        380478        6044973  Fri Jun 22 07:14:00 IST 2018    459186
# 6        345954        6162981  Fri Sep 28 10:51:00 IST 2018    471576
# 9        328440        6387425  Sat Feb 16 10:35:00 IST 2019    494802
# 12       364791        6358242  Sun Feb 03 09:25:00 IST 2019    486276
# ...         ...            ...                           ...       ...
# 1083804      -1        6272057  Wed Dec 19 11:09:00 IST 2018    458031
# 1083807  321531        6044962  Fri Jun 22 07:11:00 IST 2018    477813
# 1083810      -1        6106650  Sun Aug 12 11:53:00 IST 2018    446040
# 1083813  313131        6040298  Mon Jun 18 09:18:00 IST 2018    437976
# 1083816  324765        5945500  Fri Mar 23 06:26:00 IST 2018    470883
#
#                              ItemDescription  NumberOfItemsPurchased  \
# ...

# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
user1=data[data['UserId']==304353]
user1     # filter by userid
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 15       304353        6328674  Mon Jan 21 09:54:00 IST 2019    477246
# 5819     304353        6152762  Tue Sep 18 12:59:00 IST 2018    489258
# 11719    304353        6314308  Mon Jan 14 08:33:00 IST 2019    477246
# 29833    304353        6295685  Sat Jan 05 06:27:00 IST 2019    494991
# 33397    304353        6152762  Tue Sep 18 12:59:00 IST 2018    443856
# ...         ...            ...                           ...       ...
# 1064038  304353        6152762  Tue Sep 18 12:59:00 IST 2018    336336
# 1065168  304353        6383960  Wed Feb 13 12:14:00 IST 2019    490350
# 1071797  304353        6359320  Mon Feb 04 06:21:00 IST 2019    477246
# 1078050  304353        6152762  Tue Sep 18 12:59:00 IST 2018   1890966
# 1082597  304353        6152762  Tue Sep 18 12:59:00 IST 2018    455658
#
#                        ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# ...

# %%
import pandas as pd
data=pd.read_csv("C:/Users/srira/Downloads/archive/transaction_data.csv")
user1=data[data['Country']=='EIRE']
user1  #filter by country
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 83       297276        6196905  Sat Oct 27 10:39:00 IST 2018    474789
# 100      313131        6333261  Wed Jan 23 06:32:00 IST 2019    464898
# 181      313131        6369759  Sat Feb 09 06:31:00 IST 2019    452277
# 228      313131        6274268  Sat Dec 22 08:37:00 IST 2018    485310
# 343      313131        6255194  Mon Dec 10 08:20:00 IST 2018    442428
# ...         ...            ...                           ...       ...
# 1083397  297276        5984814  Sun Apr 29 10:49:00 IST 2018   1787079
# 1083587  313131        6312812  Sun Jan 13 09:57:00 IST 2019    450009
# 1083652  297276        6343183  Mon Jan 28 06:45:00 IST 2019    444465
# 1083799  313131        6385808  Fri Feb 15 11:28:00 IST 2019   1764651
# 1083813  313131        6040298  Mon Jun 18 09:18:00 IST 2018    437976
#
#                             ItemDescription  NumberOfItemsPurchased  \
# ...

# %%
# Filter CostPerItem is between 50 and 500
price_range = data[(data['CostPerItem'] >= 50) & (data['CostPerItem'] <= 500)]
price_range
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 72           -1        6314814  Mon Jan 14 11:33:00 IST 2019   1765638
# 799      365988        6186928  Tue Oct 16 15:22:00 IST 2018    484344
# 993      287574        6190756  Sun Oct 21 10:27:00 IST 2018        -1
# 1105     275415        6278866  Mon Dec 24 08:42:00 IST 2018   1765638
# 1293         -1        6026130  Wed Jun 06 11:50:00 IST 2018        -1
# ...         ...            ...                           ...       ...
# 1082783      -1        6108058  Mon Aug 13 13:33:00 IST 2018        -1
# 1083208      -1        6079282  Sun Jul 22 11:04:00 IST 2018        -1
# 1083250      -1        6084782  Wed Jul 25 11:53:00 IST 2018        -1
# 1083581  260715        6035271  Wed Jun 13 10:28:00 IST 2018        -1
# 1083780  259392        5998652  Sun May 13 11:52:00 IST 2018        -1
#
#                           ItemDescription  NumberOfItemsPurchased  \
# ...

# %%
# Filter the product  635534
product= data[data['ItemCode'] == 484344]
product
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 799      365988        6186928  Tue Oct 16 15:22:00 IST 2018    484344
# 19430    281148        6192065  Mon Oct 22 09:35:00 IST 2018    484344
# 33314    316659        6080943  Mon Jul 23 08:44:00 IST 2018    484344
# 35193    295848        6109400  Tue Aug 14 13:50:00 IST 2018    484344
# 40214    328062        6065554  Tue Jul 10 09:35:00 IST 2018    484344
# ...         ...            ...                           ...       ...
# 968023   354312        6249441  Wed Dec 05 12:05:00 IST 2018    484344
# 970249   313131        6279141  Mon Dec 24 09:25:00 IST 2018    484344
# 1006824      -1        6225285  Tue Nov 20 06:46:00 IST 2018    484344
# 1048431  281148        6192065  Mon Oct 22 09:35:00 IST 2018    484344
# 1058927  286818        6092834  Tue Jul 31 13:15:00 IST 2018    484344
#
#                 ItemDescription  NumberOfItemsPurchased  CostPerItem  \
# ...

# %%
# Choose 2–3 countries to display
countries = ['France', 'Germany', 'Australia']
country_data = data[data['Country'].isin(countries)]
country_data
# Out:
#          UserId  TransactionId               TransactionTime  ItemCode  \
# 2        267099        6385599  Fri Feb 15 09:45:00 IST 2019    490728
# 22       262269        5945093  Wed Mar 21 09:13:00 IST 2018    474726
# 56       260148        6249595  Fri Dec 07 07:30:00 IST 2018    488145
# 74       267183        6266689  Mon Dec 17 11:52:00 IST 2018    489699
# 116      290094        6226451  Tue Nov 20 09:48:00 IST 2018    445410
# ...         ...            ...                           ...       ...
# 1083689  263214        6181021  Sat Oct 13 06:26:00 IST 2018   1784538
# 1083769  260715        6126087  Mon Aug 27 09:37:00 IST 2018    488103
# 1083782  266994        6377712  Mon Feb 11 11:43:00 IST 2019    468846
# 1083788  266805        6358264  Sun Feb 03 09:27:00 IST 2019   1786029
# 1083803  290115        5962880  Sun Apr 08 08:16:00 IST 2018    452781
#
#                              ItemDescription  NumberOfItemsPurchased  \
# ...
